# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
for dirname, _, filenames in os.walk('test.csv'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px           # simple and easy to use
import plotly.graph_objects as go     # more control over the figure
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Batting_test

# %%
test = pd.read_csv('test.csv')
test
# Out:
#       Unnamed: 0                Player       Span  Mat Inns  NO   Runs    HS  \
# 0              0  SR Tendulkar (INDIA)  1989-2013  200  329  33  15921  248*
# 1              1      RT Ponting (AUS)  1995-2012  168  287  29  13378   257
# 2              2    JH Kallis (ICC/SA)  1995-2013  166  280  40  13289   224
# 3              3  R Dravid (ICC/INDIA)  1996-2012  164  286  32  13288   270
# 4              4         AN Cook (ENG)  2006-2018  161  291  16  12472   294
# ...          ...                   ...        ...  ...  ...  ..    ...   ...
# 2996          46       CA Snedden (NZ)  1947-1947    1    -   -      -     -
# 2997          47      VN Swamy (INDIA)  1955-1955    1    -   -      -     -
# 2998          48  Usman Shinwari (PAK)  2019-2019    1    -   -      -     -
# 2999          49    CM Willoughby (SA)  2003-2003    2    -   -      -     -
# 3000           0       JW Wilson (AUS)  1956-1956    1    -   -      -     -
#
#         Ave 100  50   0  Unnamed: 11
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
#Number of rows and Cols
test.shape
# Out:
# (3001, 13)

# %%
#  fetch the first n rows
test.head(20)
# Out:
#     Unnamed: 0                    Player       Span  Mat Inns  NO   Runs  \
# 0            0      SR Tendulkar (INDIA)  1989-2013  200  329  33  15921
# 1            1          RT Ponting (AUS)  1995-2012  168  287  29  13378
# 2            2        JH Kallis (ICC/SA)  1995-2013  166  280  40  13289
# 3            3      R Dravid (ICC/INDIA)  1996-2012  164  286  32  13288
# 4            4             AN Cook (ENG)  2006-2018  161  291  16  12472
# 5            5        KC Sangakkara (SL)  2000-2015  134  233  17  12400
# 6            6          BC Lara (ICC/WI)  1990-2006  131  232   6  11953
# 7            7        S Chanderpaul (WI)  1994-2015  164  280  49  11867
# 8            8     DPMD Jayawardene (SL)  1997-2014  149  252  15  11814
# 9            9           AR Border (AUS)  1978-1994  156  265  44  11174
# 10          10            SR Waugh (AUS)  1985-2004  168  260  46  10927
# 11          11       SM Gavaskar (INDIA)  1971-1987  125  214  16  10122
# ...

# %%
#data types check
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3001 entries, 0 to 3000
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   3001 non-null   int64
#  1   Player       3001 non-null   object
#  2   Span         3001 non-null   object
#  3   Mat          3001 non-null   int64
#  4   Inns         3001 non-null   object
#  5   NO           3001 non-null   object
#  6   Runs         3001 non-null   object
#  7   HS           3001 non-null   object
#  8   Ave          3001 non-null   object
#  9   100          3001 non-null   object
#  10  50           3001 non-null   object
#  11  0            3001 non-null   object
#  12  Unnamed: 11  0 non-null      float64
# dtypes: float64(1), int64(2), object(10)
# memory usage: 304.9+ KB

# %%
#summary check
test.describe()
# Out:
#         Unnamed: 0          Mat  Unnamed: 11
# count  3001.000000  3001.000000          0.0
# mean     24.491836    17.427191          NaN
# std      14.437798    24.954654          NaN
# min       0.000000     1.000000          NaN
# 25%      12.000000     2.000000          NaN
# 50%      24.000000     7.000000          NaN
# 75%      37.000000    21.000000          NaN
# max      49.000000   200.000000          NaN

# %%
#check for null values
test.columns[test.isnull().any()], test.isnull().sum()
# Out:
# (Index(['Unnamed: 11'], dtype='object'),
#  Unnamed: 0        0
#  Player            0
#  Span              0
#  Mat               0
#  Inns              0
#  NO                0
#  Runs              0
#  HS                0
#  Ave               0
#  100               0
#  50                0
#  0                 0
#  Unnamed: 11    3001
#  dtype: int64)

# %%
#delete unnamed: 0 column
test = test.drop(['Unnamed: 0', 'Unnamed: 11'], axis=1)
test.head()
# Out:
#                  Player       Span  Mat Inns  NO   Runs    HS    Ave 100  50  \
# 0  SR Tendulkar (INDIA)  1989-2013  200  329  33  15921  248*  53.78  51  68
# 1      RT Ponting (AUS)  1995-2012  168  287  29  13378   257  51.85  41  62
# 2    JH Kallis (ICC/SA)  1995-2013  166  280  40  13289   224  55.37  45  58
# 3  R Dravid (ICC/INDIA)  1996-2012  164  286  32  13288   270  52.31  36  63
# 4         AN Cook (ENG)  2006-2018  161  291  16  12472   294  45.35  33  57
#
#     0
# 0  14
# 1  17
# 2  16
# 3   8
# 4   9

# %%
#remove ( from column player and split into region column)
test[['Player', 'Region']] = test['Player'].str.split("(", n=1, expand=True)
test.head()
# Out:
#           Player       Span  Mat Inns  NO   Runs    HS    Ave 100  50   0  \
# 0  SR Tendulkar   1989-2013  200  329  33  15921  248*  53.78  51  68  14
# 1    RT Ponting   1995-2012  168  287  29  13378   257  51.85  41  62  17
# 2     JH Kallis   1995-2013  166  280  40  13289   224  55.37  45  58  16
# 3      R Dravid   1996-2012  164  286  32  13288   270  52.31  36  63   8
# 4       AN Cook   2006-2018  161  291  16  12472   294  45.35  33  57   9
#
#        Region
# 0      INDIA)
# 1        AUS)
# 2     ICC/SA)
# 3  ICC/INDIA)
# 4        ENG)

# %%
#removing ) from region column
test['Region'] = test['Region'].map(lambda x: x.rstrip(')'))
test.head(2)
# Out:
#           Player       Span  Mat Inns  NO   Runs    HS    Ave 100  50   0  \
# 0  SR Tendulkar   1989-2013  200  329  33  15921  248*  53.78  51  68  14
# 1    RT Ponting   1995-2012  168  287  29  13378   257  51.85  41  62  17
#
#   Region
# 0  INDIA
# 1    AUS

# %%
#split span column into start and end year
test[['Start', 'End']] = test['Span'].str.split("-", n=1, expand=True)
test.head(2)
# Out:
#           Player       Span  Mat Inns  NO   Runs    HS    Ave 100  50   0  \
# 0  SR Tendulkar   1989-2013  200  329  33  15921  248*  53.78  51  68  14
# 1    RT Ponting   1995-2012  168  287  29  13378   257  51.85  41  62  17
#
#   Region Start   End
# 0  INDIA  1989  2013
# 1    AUS  1995  2012

# %%
#split region column into region1 and region2
test[['Region1', 'Region']] = test['Region'].str.split("/", n=1, expand=True)
test.head(2)
# Out:
#           Player       Span  Mat Inns  NO   Runs    HS    Ave 100  50   0  \
# 0  SR Tendulkar   1989-2013  200  329  33  15921  248*  53.78  51  68  14
# 1    RT Ponting   1995-2012  168  287  29  13378   257  51.85  41  62  17
#
#   Region Start   End Region1
# 0   None  1989  2013   INDIA
# 1   None  1995  2012     AUS

# %%
#split region1 column into region2
#test[['Region2', 'Region']] = test['Region'].str.split("/", n=1, expand=True)
#test.head(2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 2
#       1 #split region1 column into region2
# ----> 2 test[['Region2', 'Region']] = test['Region'].str.split("/", n=1, expand=True)
#       3 test.head(2)
#
# File c:\Users\harsh\miniconda3\lib\site-packages\pandas\core\frame.py:3968, in DataFrame.__setitem__(self, key, value)
#    3966     self._setitem_frame(key, value)
#    3967 elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3968     self._setitem_array(key, value)
#    3969 elif isinstance(value, DataFrame):
#    3970     self._set_item_frame_value(key, value)
#
# File c:\Users\harsh\miniconda3\lib\site-packages\pandas\core\frame.py:4010, in DataFrame._setitem_array(self, key, value)
#    4005 else:
#    4006     # Note: unlike self.iloc[:, indexer] = value, this will
#    4007     #  never try to overwrite values inplace
# ...
